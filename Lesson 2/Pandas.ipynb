# %%
import pandas as pd

# %%
df =pd.DataFrame(
    data = {"a": ['c', 'b'], 'd': ['f', 'g']}
)

# %%
df
# Out:
#    a  d
# 0  c  f
# 1  b  g

# %%
df['a']
# Out:
# 0    c
# 1    b
# Name: a, dtype: object

# %%
df.loc[0]
# Out:
# a    c
# d    f
# Name: 0, dtype: object

# %%
df.iloc[0, 0]
# Out:
# 'c'

# %%
df.loc[0, "a"]
# Out:
# 'c'

# %%
df["s"] = ['t', 'p']

# %%
df
# Out:
#    a  d  s
# 0  c  f  t
# 1  b  g  p

# %%
df.append([{'a': 'x'}])
# Out:
# C:\Users\v_dzh\AppData\Local\Temp\ipykernel_14552\1677925755.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append([{'a': 'x'}])
#    a    d    s
# 0  c    f    t
# 1  b    g    p
# 0  x  NaN  NaN

# %%
df
# Out:
#    a  d  s
# 0  c  f  t
# 1  b  g  p

# %%
pd.concat([df, df])
# Out:
#    a  d  s
# 0  c  f  t
# 1  b  g  p
# 0  c  f  t
# 1  b  g  p

# %%
# %%timeit

df =pd.DataFrame(
    data = {"a": ['c', 'b'], 'd': ['f', 'g']}
)

for i in range(100):
    df = df.append([{'a': 'x'}])
# Out:
# <magic-timeit>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <magic-timeit>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <magic-timeit>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <magic-timeit>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <magic-timeit>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <magic-timeit>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df =pd.DataFrame(
    data = {"a": ['c', 'b'], 'd': ['f', 'g']}
)

# %%
df.to_csv('test.csv')

# %%
df.shape
# Out:
# (2, 2)

# %%
df.columns
# Out:
# Index(['a', 'd'], dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of    a  d
# 0  c  f
# 1  b  g>

# %%
df.describe()
# Out:
#         a  d
# count   2  2
# unique  2  2
# top     c  f
# freq    1  1
